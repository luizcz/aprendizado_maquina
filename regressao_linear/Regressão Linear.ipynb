# %% [markdown]
# Programa criado acompanhanho o vídeo de Siraj Raval que pode ser encontrado nesse [link](https://www.youtube.com/watch?v=XdM6ER7zTLk). O dados foram obtidos no github do autor do vídeo que pode ser acessado nesse [link](https://github.com/llSourcell/linear_regression_live).

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from numpy import *

# y = mx + b
# m is slope, b is y-intercept
def compute_error_for_given_points(b, m, points):
    totalError = 0
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        totalError += (y - (m * x + b)) ** 2
    return totalError / float(len(points))

def step_gradient(b_current, m_current, points, learningRate):
    b_gradient = 0
    m_gradient = 0
    N = float(len(points))
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        b_gradient += -(2/N) * (y - ((m_current * x) + b_current))
        m_gradient += -(2/N) * x * (y - ((m_current * x) + b_current))
    new_b = b_current - (learningRate * b_gradient)
    new_m = m_current - (learningRate * m_gradient)
    return [new_b, new_m]

def gradient_descent_runner(points, starting_b, starting_m, learning_rate, num_iterations):
    b = starting_b
    m = starting_m
    for i in range(num_iterations):
        b, m = step_gradient(b, m, array(points), learning_rate)
    return [b, m]

def run():
    points = genfromtxt("data.csv", delimiter=",")
    learning_rate = 0.0001
    initial_b = 0 # initial y-intercept guess
    initial_m = 0 # initial slope guess
    num_iterations = 1000
    print("Starting gradient descent at b = {0}, m = {1}, error = {2}".format(initial_b, initial_m, compute_error_for_line_given_points(initial_b, initial_m, points)))
    print("Running...")
    [b, m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations)
    print("After {0} iterations b = {1}, m = {2}, error = {3}".format(num_iterations, b, m, compute_error_for_line_given_points(b, m, points)))

if __name__ == '__main__':
    run()
# Out:
# Starting gradient descent at b = 0, m = 0, error = 5565.107834483211
# Running...
# After 1000 iterations b = 0.08893651993741346, m = 1.4777440851894448, error = 112.61481011613473

# %% [markdown]
# ### 1 - Rode o mesmo programa nos dados contendo anos de escolaridade (primeira coluna) versus salário (segunda coluna). Baixe os dados no income.csv. Esse exemplo foi trabalhado em sala de aula.

# %%
def run():
    points = genfromtxt('income.csv', delimiter = ',')
    #hyperparameters 
    learning_rate = 0.0001
    #y= mx +b (slope formula)
    initial_b = 0
    initial_m = 0
    num_iterations = 1000
    print("Starting gradient descent at b = {0}, m = {1}, error = {2}".format(initial_b, initial_m, compute_error_for_given_points(initial_b, initial_m, points)))
    print("Running...")
    [b,m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations)
    print ("After {0} iterations b = {1}, m = {2}, error = {3}".format(num_iterations, b, m, compute_error_for_given_points(b, m, points)))
    

if __name__ == '__main__':
    run()
# Out:
# Starting gradient descent at b = 0, m = 0, error = 2946.6344970460195
# Running...
# After 1000 iterations b = -0.18234255376510086, m = 3.262182267596014, error = 103.39842291729676

# %% [markdown]
# ### 2 - Modifique o código original para imprimir o RSS a cada iteração do gradiente descendente.

# %%
def gradient_descent_runner(points, starting_b, starting_m, learning_rate, num_iterations):
    b = starting_b
    m = starting_m
    
    for i in range(num_iterations):
        b, m = step_gradient(b, m, array(points), learning_rate)
        print ("After {0} iterations the error is {1}".format(i, compute_error_for_given_points(b, m, points)))
    return [b,m]

def run():
    points = genfromtxt('income.csv', delimiter = ',')
    #hyperparameters 
    learning_rate = 0.0001
    #y= mx +b (slope formula)
    initial_b = 0
    initial_m = 0
    num_iterations = 1000
    print("Starting gradient descent at b = {0}, m = {1}, error = {2}".format(initial_b, initial_m, compute_error_for_given_points(initial_b, initial_m, points)))
    print("Running...")
    [b,m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations)
    print ("After {0} iterations b = {1}, m = {2}, error = {3}".format(num_iterations, b, m, compute_error_for_given_points(b, m, points)))
    

if __name__ == '__main__':
    run()
# Out:
# Starting gradient descent at b = 0, m = 0, error = 2946.6344970460195
# Running...
# After 0 iterations the error is 2648.2381266261386
# After 1 iterations the error is 2381.1735926230144
# After 2 iterations the error is 2142.151013653971
# After 3 iterations the error is 1928.2259499305476
# After 4 iterations the error is 1736.7631314659504
# After 5 iterations the error is 1565.4039948653665
# After 6 iterations the error is 1412.0376287932477
# After 7 iterations the error is 1274.7747702022896
# After 8 iterations the error is 1151.924530990372
# After 9 iterations the error is 1041.9735683871631
# After 10 iterations the error is 943.5674424757678
# After 11 iterations the error is 855.4939311975465
# After 12 iterations the error is 776.6680973019634
# After 13 iterations the error is 706.1189232850785
# After 14 iterations the error is 642.9773496759485
# After 15 iterations the error is 586.4655693176774
# After 16 iterations the error is 535.8874457621318
# ...

# %% [markdown]
# ### 3 - O que acontece com o RSS ao longo das iterações (aumenta ou diminui) se você usar 1000 iterações? Plote o RSS vs número de iterações.

# %%
#from matplotlib import pyplot as plt
eixo_x = []
eixo_y = []
def gradient_descent_runner(points, starting_b, starting_m, learning_rate, num_iterations):
    b = starting_b
    m = starting_m
    
    for i in range(num_iterations):
        b, m = step_gradient(b, m, array(points), learning_rate)
        eixo_x.append(i)
        eixo_y.append(compute_error_for_given_points(b, m, points))
        #print ("After {0} iterations the error is {1}".format(i, ))
    return [b,m]

def run():
    points = genfromtxt('income.csv', delimiter = ',')
    #hyperparameters 
    learning_rate = 0.0001
    #y= mx +b (slope formula)
    initial_b = 0
    initial_m = 0
    num_iterations = 1000
    #print("Starting gradient descent at b = {0}, m = {1}, error = {2}".format(initial_b, initial_m, compute_error_for_given_points(initial_b, initial_m, points)))
    #print("Running...")
    [b,m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations)
    plt.plot(eixo_x, eixo_y)
    plt.xlabel("Número de iterações")
    plt.ylabel("RSS")
    plt.show()
    #print ("After {0} iterations b = {1}, m = {2}, error = {3}".format(num_iterations, b, m, compute_error_for_given_points(b, m, points)))
    

if __name__ == '__main__':
    run()

# %% [markdown]
# ### 4 - Teste valores diferentes do número de iterações e learning_rate até que w0 e w1 sejam aproximadamente iguais a -39 e 5 respectivamente. Reporte os valores do número de iterações e learning_rate usados para atingir esses valores.

# %%
def run():
    points = genfromtxt('income.csv', delimiter = ',')
    #hyperparameters 
    learning_rate = 0.0001
    #y= mx +b (slope formula)
    initial_b = 0
    initial_m = 0
    num_iterations = 1000
    while(True):
        print("Learning rate = {0} e Número de iterações = {1}".format(learning_rate, num_iterations))
        print("Starting gradient descent at b = {0}, m = {1}, error = {2}".format(initial_b, initial_m, compute_error_for_given_points(initial_b, initial_m, points)))
        print("Running...")
        [b,m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations)
        print ("After {0} iterations b = {1}, m = {2}, error = {3}".format(num_iterations, b, m, compute_error_for_given_points(b, m, points)))
        num_iterations = num_iterations * 2
        learning_rate = learning_rate * 2
        if(int(b) == -39 and int(m) == 5):
            break
    

if __name__ == '__main__':
    run()
# Out:
# Learning rate = 0.0001 e Número de iterações = 1000
# Starting gradient descent at b = 0, m = 0, error = 2946.6344970460195
# Running...
# After 1000 iterations b = -0.18234255376510086, m = 3.262182267596014, error = 103.39842291729676
# Learning rate = 0.0002 e Número de iterações = 2000
# Starting gradient descent at b = 0, m = 0, error = 2946.6344970460195
# Running...
# After 2000 iterations b = -1.286786752941453, m = 3.3279275748103365, error = 99.31779327268153
# Learning rate = 0.0004 e Número de iterações = 4000
# Starting gradient descent at b = 0, m = 0, error = 2946.6344970460195
# Running...
# After 4000 iterations b = -5.402556923349077, m = 3.5729309660896726, error = 85.13640882618984
# Learning rate = 0.0008 e Número de iterações = 8000
# Starting gradient descent at b = 0, m = 0, error = 2946.6344970460195
# Running...
# After 8000 iterations b = -17.880235608658126, m = 4.315701691038057, error = 52.02361959859582
# ...

# %% [markdown]
# Os valores que foram utilizados para chegar a esses valores são __learning_rate = 0.0032__ e __Número de iterações = 32000__

# %% [markdown]
# ### 5 - O algoritmo do vídeo usa o número de iterações como critério de parada. Mude o algoritmo para considerar um critério de parada que é relacionado ao tamanho do gradiente (como no algoritmo apresentado em sala). Plote o tamanho do gradiente vs número de iterações.

# %%
eixo_x = []
eixo_y = []
def step_gradient(b_current, m_current, points, learningRate):
    b_gradient = 0
    m_gradient = 0
    N = float(len(points))
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        b_gradient += -(2/N) * (y - ((m_current * x) + b_current))
        m_gradient += -(2/N) * x * (y - ((m_current * x) + b_current))
    new_b = b_current - (learningRate * b_gradient)
    new_m = m_current - (learningRate * m_gradient)
    return [new_b, new_m, b_gradient, m_gradient]

def gradient_descent_runner(points, starting_b, starting_m, learning_rate, num_iterations):
    b = starting_b
    m = starting_m
    ite = 0
    
    while(True):
        b, m, bg, mg = step_gradient(b, m, array(points), learning_rate)
        ite += 1
        eixo_x.append(ite)
        eixo_y.append(sqrt(bg**2 + mg**2))
        if(sqrt(bg**2 + mg**2) < 1):
            break
        #print ("After {0} iterations the error is {1}".format(i, ))
    return [b,m]
def run():
    points = genfromtxt("income.csv", delimiter=",")
    learning_rate = 0.0032
    initial_b = 0 # initial y-intercept guess
    initial_m = 0 # initial slope guess
    num_iterations = 1000
    #print("Starting gradient descent at b = {0}, m = {1}, error = {2}".format(initial_b, initial_m, compute_error_for_line_given_points(initial_b, initial_m, points)))
    #print("Running...")
    [b, m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations)
    print(" b = {0}, m = {1}, error = {2}".format(b, m, compute_error_for_line_given_points(b, m, points)))
    plt.plot(eixo_x, eixo_y)
    plt.xlabel("Número de iterações")
    plt.ylabel("Tamanho do gradiente")
    plt.show()
    print("Dado que não ficou muito claro o comportamento no gráfico, é possível aplicar escala no eixo x de modo que fique mais visível")
    plt.plot(eixo_x, eixo_y)
    plt.xlabel("Número de iterações")
    plt.ylabel("Tamanho do gradiente")
    plt.xscale("log")
    plt.show()

if __name__ == '__main__':
    run()
# Out:
#  b = -28.95466875268457, m = 4.974940075214896, error = 35.08165050023228
# Dado que não ficou muito claro o comportamento no gráfico, é possível aplicar escala no eixo x de modo que fique mais visível

# %% [markdown]
# ### 6 - Ache um valor de tolerância que se aproxime dos valores dos parâmetros do item 4 acima. Que valor foi esse?

# %%
eixo_x = []
eixo_y = []
def step_gradient(b_current, m_current, points, learningRate):
    b_gradient = 0
    m_gradient = 0
    N = float(len(points))
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        b_gradient += -(2/N) * (y - ((m_current * x) + b_current))
        m_gradient += -(2/N) * x * (y - ((m_current * x) + b_current))
    new_b = b_current - (learningRate * b_gradient)
    new_m = m_current - (learningRate * m_gradient)
    return [new_b, new_m, b_gradient, m_gradient]

def gradient_descent_runner(points, starting_b, starting_m, learning_rate, tolerancia):
    b = starting_b
    m = starting_m
    ite = 0
    
    while(True):
        b, m, bg, mg = step_gradient(b, m, array(points), learning_rate)
        ite += 1
        eixo_x.append(ite)
        eixo_y.append(sqrt(bg**2 + mg**2))
        if(sqrt(bg**2 + mg**2) < tolerancia):
            break
        #print ("After {0} iterations the error is {1}".format(i, ))
    return [b,m]
def run():
    points = genfromtxt("income.csv", delimiter=",")
    learning_rate = 0.0032
    initial_b = 0 # initial y-intercept guess
    initial_m = 0 # initial slope guess
    tolerancia = 1
    #print("Starting gradient descent at b = {0}, m = {1}, error = {2}".format(initial_b, initial_m, compute_error_for_line_given_points(initial_b, initial_m, points)))
    #print("Running...")
    while(True):
        [b, m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate, tolerancia)
        tolerancia = tolerancia - 0.01
        print("b= {0} m= {1} tolerancia = {2}".format(b, m , tolerancia))
        if(-39 == int(b) and 5 == int(m)):
            break
    print("b = {0}, m = {1}, error = {2}".format( b, m, compute_error_for_line_given_points(b, m, points)))


if __name__ == '__main__':
    run()
# Out:
# b= -28.95466875268457 m= 4.974940075214896 tolerancia = 0.99
# b= -29.05952562650069 m= 4.981181990730153 tolerancia = 0.98
# b= -29.163334521301294 m= 4.9873615221952425 tolerancia = 0.97
# b= -29.269204109202068 m= 4.993663722511367 tolerancia = 0.96
# b= -29.373983698611145 m= 4.999901037443735 tolerancia = 0.95
# b= -29.480718318782873 m= 5.006254731364014 tolerancia = 0.94
# b= -29.583320227386853 m= 5.012362413406235 tolerancia = 0.9299999999999999
# b= -29.690806384396975 m= 5.018760844779398 tolerancia = 0.9199999999999999
# b= -29.794183674093773 m= 5.024914683674264 tolerancia = 0.9099999999999999
# b= -29.89937184392215 m= 5.031176320564416 tolerancia = 0.8999999999999999
# b= -30.003413674402893 m= 5.0373697182147446 tolerancia = 0.8899999999999999
# b= -30.10916414766905 m= 5.043664827879976 tolerancia = 0.8799999999999999
# b= -30.21373032055127 m= 5.049889438562429 tolerancia = 0.8699999999999999
# ...

# %% [markdown]
# A tolerancia utilizada para atingir esse valor é de __0,0299__
